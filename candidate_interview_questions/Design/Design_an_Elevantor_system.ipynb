# %% [markdown]
# # Design an elevator system for a building

# %% [markdown]
# Componants:
#
#
# - ElevatorSystem (floors, elevators, security service, saftey service)
# - Elevator (is_idle, is_up, is_down, request_floor, go_up, go_down, open_doors, close_doors)
# - FloorInterace (request up, request down)

# %%
class ElevatorSystem:
    
    def __init__(self, floors, elevators, security_service, saftey_service):
        self.floors = floors
        self.elevators = elevators
        self.security_service = security_service
        self.saftey_service = saftey_service
        self.call_queue = [] # floors will call 
        
    def add_elevator(self, elevator):
        try:
            if elevator.id in self.elevators:
                self.elevators.pop(elevator.id)
            self.elevators[elevator.id] = elevator
            return 0

        except:
            return 1
            
    def remove_elevator(self, elevator):
        try:
            self.elevators.pop(elevator.id)
            return 0
        except:
            return 1
        
    def add_floor(self, floor):
        try:
            if floor.id in self.floors:
                self.floors.pop(floor.id)
            self.floors[floor.id] = 1
            return 0
        except:
            return 1
        
    def remove_floor(self, floor):
        pass
    
    def call_elevator(self)
    
    
class security_service:
    pass

class saftey_service:
    pass

class Elevator:
    
    def __init__(self, id, floor):
        self.id = id
        self.doors_open = False
        self.going_up = False
        self.going_down = False
        self.is_idle = True
        self.elevator_service = None
        self.location = floor
        self.floor_queue = []
        
    def connect(self, elevator_service):
        self.elevator_service = elevator_service
        return self.elevator_service.add_elevator(self)
    
    def disconnect(self, )
    
    
    def close_door()
    
    def go_next(self):
        
        if  len(self.floor_queue) == 0:
            self.idle
        
    def go_down(self, floor):
        pass
    
    def
