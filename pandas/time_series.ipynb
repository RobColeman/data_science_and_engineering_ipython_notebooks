# %%
# %matplotlib inline
#%load_ext autoreload
#%autoreload 2
# %reload_ext autoreload
import numpy as np
import matplotlib.pyplot as plt
import math, sys, os
from numpy.random import randn

# and pandas
import pandas as pd

# %%
daily_returns = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
daily_returns.plot()

# %%
daily_price = daily_returns.cumsum()
daily_price.plot()

# %%
A = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
B = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
C = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
D = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
E = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))

# %%
returns = pd.concat([A,B,C,D,E],axis=1,keys=['A', 'B', 'C', 'D', 'E'])
prices = stock_returns.cumsum()
returns.head()
# Out:
#                    A         B         C         D         E
# 2015-01-01  2.612078  0.374134  0.272754 -0.898466 -0.055529
# 2015-01-02 -1.600442  1.306431 -0.342925  0.905055 -0.553716
# 2015-01-03 -1.025235 -0.468725 -1.890469 -0.806972 -0.730445
# 2015-01-04  1.284857 -1.525487 -0.356687  1.628839  0.961029
# 2015-01-05 -1.097391 -1.796061 -0.483691 -0.824774 -0.867467

# %%
returns.plot()

# %%
prices.plot()

# %%
returns.cov()
# Out:
#           A         B         C         D         E
# A  1.007231 -0.008451 -0.009538 -0.003638 -0.020547
# B -0.008451  0.962290  0.027404  0.001186  0.031077
# C -0.009538  0.027404  1.045023  0.042157  0.021391
# D -0.003638  0.001186  0.042157  0.952640 -0.045342
# E -0.020547  0.031077  0.021391 -0.045342  0.996117

# %%
returns.corr()
# Out:
#           A         B         C         D         E
# A  1.000000 -0.008584 -0.009297 -0.003713 -0.020513
# B -0.008584  1.000000  0.027327  0.001238  0.031742
# C -0.009297  0.027327  1.000000  0.042252  0.020966
# D -0.003713  0.001238  0.042252  1.000000 -0.046546
# E -0.020513  0.031742  0.020966 -0.046546  1.000000

# %%
prices.corr()
# Out:
#           A         B         C         D         E
# A  1.000000  0.576753  0.221313 -0.085390 -0.423617
# B  0.576753  1.000000  0.240232 -0.615558 -0.592174
# C  0.221313  0.240232  1.000000 -0.080393 -0.095738
# D -0.085390 -0.615558 -0.080393  1.000000  0.390983
# E -0.423617 -0.592174 -0.095738  0.390983  1.000000

# %%
prices.cov()
# Out:
#             A           B          C           D          E
# A  101.695864   78.924930  15.136443  -11.222303 -35.296643
# B   78.924930  184.138573  22.108974 -108.859173 -66.394136
# C   15.136443   22.108974  45.997179   -7.105710  -5.364837
# D  -11.222303 -108.859173  -7.105710  169.842627  42.100755
# E  -35.296643  -66.394136  -5.364837   42.100755  68.267886
